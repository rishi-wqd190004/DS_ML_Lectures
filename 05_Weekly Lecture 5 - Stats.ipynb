# %% [markdown]
# # Previous Week

# %% [markdown]
#  - University Management System - Scratch
#  - Random Password Generator
#  - Text Cipher-Decipher

# %% [markdown]
# # This Week

# %% [markdown]
# ## Statistics in data science
#  - Topics:
#
#         - Population: the source of data to be collected.
#         - Sample: a portion of the population.
#         - Variable: any data item that can be measured or counted.
#         - Quantitative analysis (statistical): collecting and interpreting data with patterns and data visualization.
#         - Qualitative analysis (non-statistical): producing generic information from other non-data forms of media.
#         - Descriptive statistics: characteristics of a population.
#         - Inferential statistics: predictions for a population.
#         - Central tendency (measures of the center): mean (average of all values), median (central value of a data set), and mode (the most recurrent value in a data set).
#         - Measures of the spread:
#             - Range: the distance between each value in a data set.
#             - Variance: the distance between a variable and its expected value.
#             - Standard deviation: the dispersion of a data set from the mean.

# %% [markdown]
# # Getting Started with Pandas

# %% [markdown]
# - The pandas package is the most important tool at the disposal of Data Scientists and Analysts working in Python today. The powerful machine learning and glamorous visualization tools may get all the attention, but pandas is the backbone of most data projects.

# %% [markdown]
# ## What's Pandas for?
#  - Pandas has so many uses that it might make sense to list the things it can't do instead of what it can do.
#  - This tool is essentially your data’s home. Through pandas, you get acquainted with your data by cleaning, transforming, and analyzing it.

# %% [markdown]
# # Pandas First Steps

# %% [markdown]
# ## Install and import
#  - Pandas is an easy package to install. Open up your terminal program (for Mac users) or command line (for PC users) and install it using either of the following commands:

# %%
conda install pandas
pip install pandas

# %% [markdown]
# ## Alternatively, if you're currently viewing this article in a Jupyter notebook you can run this cell

# %%
# !pip install pandas

# %% [markdown]
# ## To import pandas we usually import it with a shorter name since it's used so much:

# %%
import pandas
pandas.__version__
# Out:
# '2.0.3'

# %% [markdown]
# # Core components of pandas: Series and DataFrames

# %% [markdown]
#  - The primary two components of pandas are the Series and DataFrame.
#
# - A Series is essentially a column, and a DataFrame is a multi-dimensional table made up of a collection of Series.
#      - In other words a Series is a 1-Dimensional array

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - DataFrames and Series are quite similar in that many operations that you can do with one you can do with the other, such as filling in null values and calculating the mean.

# %% [markdown]
# # Creating DataFrames from scratch

# %% [markdown]
# - Creating DataFrames right in Python is good to know and quite useful when testing new methods and functions you find in the pandas docs.
#
# - There are many ways to create a DataFrame from scratch, but a great option is to just use a simple dict.

# %%
data = {
    'apples': [3, 2, 0, 1], 
    'oranges': [0, 3, 7, 2]
}

# %%
import pandas as pd
import numpy as np

purchases = pd.DataFrame(data)
purchases
# Out:
#    apples  oranges  pineapple
# 0       3        0          0
# 1       2        3          1
# 2       0        7          2
# 3       1        2          3

# %%
print(type(purchases))
print(type(purchases['apples']))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>

# %%
purchases = pd.DataFrame(data, index=['June', 'Robert', 'Lily', 'David'])
purchases.to_csv('purchases.csv')

# %%
purchases_2 = pd.DataFrame(data, index=['June', 'Robert', 'Lily', 'David', 'Rishi'])
purchases_2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 purchases_2 = pd.DataFrame(data, index=['June', 'Robert', 'Lily', 'David', 'Rishi'])
#       2 purchases_2
#
# File ~/miniconda3/envs/onl_capbl/lib/python3.11/site-packages/pandas/core/frame.py:709, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     703     mgr = self._init_mgr(
#     704         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     705     )
#     707 elif isinstance(data, dict):
#     708     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 709     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     710 elif isinstance(data, ma.MaskedArray):
#     711     from numpy.ma import mrecords
#
# File ~/miniconda3/envs/onl_capbl/lib/python3.11/site-packages/pandas/core/internals/construction.py:481, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     477     else:
#     478         # dtype check to exclude e.g. range objects, scalars
#     479         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 481 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~/miniconda3/envs/onl_capbl/lib/python3.11/site-packages/pandas/core/internals/construction.py:120, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     117         index = ensure_index(index)
#     119     # don't force copy because getting jammed in an ndarray anyway
# --> 120     arrays, refs = _homogenize(arrays, index, dtype)
#     121     # _homogenize ensures
#     122     #  - all(len(x) == len(index) for x in arrays)
#     123     #  - all(x.ndim == 1 for x in arrays)
#    (...)
#     126
#     127 else:
#     128     index = ensure_index(index)
#
# File ~/miniconda3/envs/onl_capbl/lib/python3.11/site-packages/pandas/core/internals/construction.py:608, in _homogenize(data, index, dtype)
#     605         val = lib.fast_multiget(val, oindex._values, default=np.nan)
#     607     val = sanitize_array(val, index, dtype=dtype, copy=False)
# --> 608     com.require_length_match(val, index)
#     609     refs.append(None)
#     611 homogenized.append(val)
#
# File ~/miniconda3/envs/onl_capbl/lib/python3.11/site-packages/pandas/core/common.py:576, in require_length_match(data, index)
#     572 """
#     573 Check the length of data matches the length of the index.
#     574 """
#     575 if len(data) != len(index):
# --> 576     raise ValueError(
#     577         "Length of values "
#     578         f"({len(data)}) "
#     579         "does not match length of index "
#     580         f"({len(index)})"
#     581     )
#
# ValueError: Length of values (4) does not match length of index (5)

# %%
purchases
# Out:
#         apples  oranges
# June         3        0
# Robert       2        3
# Lily         0        7
# David        1        2

# %%
data = {
    'apples': [3, 2, 0, 1], 
    'oranges': [0, 3, 7, 2],
    'pineapple': [0,1,pd.NaT,pd.NA]
}

df = pd.DataFrame(data)
print(df)
# Out:
#    apples  oranges pineapple
# 0       3        0         0
# 1       2        3         1
# 2       0        7       NaT
# 3       1        2      <NA>

# %% [markdown]
# ## So now we could locate a customer's order by using their name:

# %%
purchases.loc['June']
# Out:
# apples     3
# oranges    0
# Name: June, dtype: int64

# %% [markdown]
# # How to read in data

# %%
df = pd.read_csv("purchases.csv", index_col=0)
#df_ = pd.read
df.tail(2)
# Out:
#        apples  oranges
# Lily        0        7
# David       1        2

# %% [markdown]
# # Understanding your data using Pandas

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, June to David
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   apples   4 non-null      int64
#  1   oranges  4 non-null      int64
# dtypes: int64(2)
# memory usage: 96.0+ bytes

# %%
df.shape #(row, columm)
# Out:
# (4, 2)

# %%
df.describe()
# Out:
#          apples  oranges
# count  4.000000  4.00000
# mean   1.500000  3.00000
# std    1.290994  2.94392
# min    0.000000  0.00000
# 25%    0.750000  1.50000
# 50%    1.500000  2.50000
# 75%    2.250000  4.00000
# max    3.000000  7.00000

# %% [markdown]
# # Count

# %%
df['apples'].count()
df.apples.count()
# Out:
# 4

# %%
df['oranges'].count()
# Out:
# 4

# %% [markdown]
# # Mean

# %%
df['apples'].mean()
# Out:
# 1.5

# %%
df['oranges'].mean()
# Out:
# 3.0

# %% [markdown]
# # Standard Deviation

# %%
df['apples'].std()
# Out:
# 1.2909944487358056

# %%
df['oranges'].std()
# Out:
# 2.943920288775949

# %%
df['apples'].min()
# Out:
# 0

# %%
df['oranges'].min()
# Out:
# 0

# %% [markdown]
# # Min

# %%
df['apples'].min()
# Out:
# 0

# %%
df['oranges'].min()
# Out:
# 0

# %% [markdown]
# ![image.png](attachment:cc60ba15-9746-4581-8bf7-d4f058e98a8d.png)

# %% [markdown]
# Example:
#
#     - Find the median, lower quartile and upper quartile of the following numbers.
#     12, 5, 22, 30, 7, 36, 14, 42, 15, 53, 25

# %% [markdown]
# Solution:
# First, arrange the data in ascending order:
#
# ![image.gif](attachment:f63c7ad4-2267-4e41-8788-384f715cbbf6.gif)
# Median (middle value) = 22
#
# Lower quartile (middle value of the lower half) = 12
#
# Upper quartile (middle value of the upper half) = 36
#
# If there is an even number of data items, then we need to get the average of the middle numbers.

# %% [markdown]
# # 1st Quartile

# %%
df['apples'].quantile(.25)
# Out:
# 0.75

# %%
df['oranges'].quantile(.25)
# Out:
# 1.5

# %% [markdown]
# # 2nd Qartile

# %%
df['apples'].quantile(.5)
# Out:
# 1.5

# %%
df['oranges'].quantile(.5)
# Out:
# 2.5

# %%
df['apples'].median()
# Out:
# 1.5

# %%
df['oranges'].median()
# Out:
# 2.5

# %% [markdown]
# # 3rd Quartile

# %%
df['apples'].quantile(.75)
# Out:
# 2.25

# %%
df['oranges'].quantile(.75)
# Out:
# 4.0

# %% [markdown]
# # Max

# %%
df['apples'].max()
# Out:
# 3

# %%
df['oranges'].max()
# Out:
# 7

# %% [markdown]
# # Upcoming Week

# %% [markdown]
# - Dealing with Null Values
# - Dataset Preprocessing
# - Data Analysis- Categorial
# - Multi Column Analysis
# - Data Analysis with Sorting
# - Analysis with Custom DataFrames
